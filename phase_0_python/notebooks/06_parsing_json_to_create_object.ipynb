# %% [markdown]
# # Parse a JSON config (paths, model params) and dynamically build objects from it.

# %% [markdown]
# Read settings from a JSON file and use them to decide which classes to create and how to configure them, instead of hardcoding

# %% [markdown]
# I want to change my experiment by editing a file, not touching code.

# %%
# INPUT
# Path to a JSON config file

# OUTPUT
# Python objects created using values from the config
# (for example: model, paths, parameters)

# INVARIANTS
# Config values are not mutated
# Objects reflect config exactly
# No hardcoded values override config

# SIDE EFFECTS
# Reading a file from disk (allowed)
# No global state mutation
